# %%
from google_flight_analysis.scrape import *
import pandas as pd

# %%
import requests
import pandas as pd
import json 


url = "https://tripadvisor16.p.rapidapi.com/api/v1/flights/searchFlights"

querystring = {"sourceAirportCode":"BOM","destinationAirportCode":"DEL","date":"2024-04-17",
               "itineraryType":"ROUND_TRIP","sortOrder":"PRICE","numAdults":"1","numSeniors":"0",
               "classOfService":"ECONOMY","pageNumber":"1","currencyCode":"USD","returnDate":"2024-04-24"}

headers = {
	"X-RapidAPI-Key": "737c896f76msh1e78782a397adc1p124d2ajsn06a610b4e287",
	"X-RapidAPI-Host": "tripadvisor16.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())

JsonResp = response.json()
# Out:
# {'status': True, 'message': 'Success', 'timestamp': 1713264282190, 'data': {'session': {'searchHash': '3b32cd71d88d6e16d909a5388c4122ed', 'pageLoadUid': '52cf2063-8813-4389-b08e-a54e6048254d', 'searchId': '98091004-245c-4fa2-ac88-2595d4400f6b.197', 'filterSettings': {'tt': '', 'aa': 'DEL', 'a': '', 'd': '', 'ns': '', 'cos': '0', 'al': '', 'fq': '', 'ft': '', 'sid': '', 'oc': '', 'plp': '', 'mc': '', 'da': 'BOM', 'pRange': '-1,-1', 'ca': ''}}, 'complete': False, 'numOfFilters': 204, 'totalNumResults': 204, 'flights': [{'segments': [{'legs': [{'originStationCode': 'BOM', 'isDifferentOriginStation': False, 'destinationStationCode': 'HYD', 'isDifferentDestinationStation': False, 'departureDateTime': '2024-04-17T06:10:00+05:30', 'arrivalDateTime': '2024-04-17T07:45:00+05:30', 'classOfService': 'ECONOMY', 'marketingCarrierCode': 'UK', 'operatingCarrierCode': 'UK', 'equipmentId': 'Airbus A320-100/200', 'amenities': [], 'flightNumber': 873, 'seatGuruEquipmentId': 0, 'seatGuruAirlineUrl': '',
# ...

# %%
print(JsonResp['data']['flights'][1]['purchaseLinks'][0]['totalPrice'])
# Out:
# 154
