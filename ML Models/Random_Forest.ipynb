# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris  # Example dataset
from sklearn.metrics import *
from sklearn.model_selection import GridSearchCV
import joblib
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Data

# %%
# Load data

data = joblib.load('/Users/sebastian/Documents/UNI/Kandidat/2. Semester/DSP/Second Part/dsp_project/dsp_project/2. Feature engineering/housing_data_engineered.pkl')

# Inspect Data

## Set display options to show all columns
pd.set_option('display.max_columns', None)

## Now when you display your DataFrame, all columns will be shown
print(data)
# Out:
#      Year_built  Rooms  Balcony  Garden  Parking  Fireplace  Garage  Basement  \
# 0          1911      3     True    True     True       True    True     False
# 1          1930      3    False   False    False      False   False     False
# 2          1970      4    False    True     True      False   False     False
# 3          1900      4    False    True    False       True   False     False
# 4          1970      2    False   False    False      False   False     False
# ..          ...    ...      ...     ...      ...        ...     ...       ...
# 192        1872      3    False    True     True      False   False     False
# 193        1967      4    False    True     True      False    True     False
# 194        1954      2    False    True     True      False    True      True
# 195        1960      5    False    True     True      False    True     False
# 196        1972      2     True   False    False      False   False     False
#
#      Elevator  Type_Andelsbolig  Type_Ejerlejlighed  Type_Landejendom  \
# 0       False             False               False             False
# 1       False             False                True             False
# 2       False             False               False             False
# 3       False             False               False             False
# 4       False             False                True             False
# ..        ...               ...                 ...               ...
# 192     False             False               False             False
# 193     False             False               False             False
# 194     False             False               False             False
# 195     False             False               False             False
# 196      True             False                True             False
#
#      Type_Rækkehus  Type_Villa  Energy_rating_A2010  Energy_rating_A2015  \
# 0            False        True                False                False
# 1            False       False                False                False
# 2            False        True                False                False
# 3            False        True                 True                False
# 4            False       False                False                False
# ..             ...         ...                  ...                  ...
# 192          False        True                False                False
# 193          False        True                False                False
# 194          False        True                False                False
# 195          False        True                False                False
# 196          False       False                False                False
#
#      Energy_rating_B  Energy_rating_C  Energy_rating_D  Energy_rating_E  \
# 0              False            False             True            False
# 1              False            False             True            False
# 2              False            False             True            False
# 3              False            False            False            False
# 4               True            False            False            False
# ..               ...              ...              ...              ...
# 192            False            False             True            False
# 193             True            False            False            False
# 194            False            False            False            False
# 195            False             True            False            False
# 196            False             True            False            False
#
#      Energy_rating_G  Days_desc_1-10  Days_desc_100+  Days_desc_11-20  \
# 0              False           False           False            False
# 1              False           False           False            False
# 2              False           False            True            False
# 3              False            True           False            False
# 4              False            True           False            False
# ..               ...             ...             ...              ...
# 192            False           False            True            False
# 193            False           False            True            False
# 194            False           False            True            False
# 195            False           False            True            False
# 196            False           False            True            False
#
#      Days_desc_21-50  Days_desc_51-100  Municipality_Aarhus C  \
# 0              False              True                  False
# 1               True             False                   True
# 2              False             False                  False
# 3              False             False                  False
# 4              False             False                  False
# ..               ...               ...                    ...
# 192            False             False                  False
# 193            False             False                  False
# 194            False             False                  False
# 195            False             False                  False
# 196            False             False                  False
#
#      Municipality_Aarhus N  Municipality_Aarhus V  Municipality_Brabrand  \
# 0                    False                  False                  False
# 1                    False                  False                  False
# 2                    False                  False                  False
# 3                    False                  False                  False
# 4                    False                  False                  False
# ..                     ...                    ...                    ...
# 192                  False                  False                  False
# 193                  False                  False                  False
# 194                  False                  False                  False
# 195                  False                  False                  False
# 196                  False                  False                  False
#
#      Municipality_Egå  Municipality_Harlev J  Municipality_Hasselager  \
# 0               False                  False                    False
# 1               False                  False                    False
# 2               False                  False                    False
# 3               False                  False                    False
# 4               False                  False                    False
# ..                ...                    ...                      ...
# 192             False                  False                    False
# 193             False                  False                    False
# 194             False                  False                    False
# 195             False                  False                    False
# 196             False                  False                    False
#
#      Municipality_Hjortshøj  Municipality_Højbjerg  Municipality_Lystrup  \
# 0                     False                  False                 False
# 1                     False                  False                 False
# 2                     False                  False                 False
# 3                     False                  False                 False
# 4                     False                  False                 False
# ..                      ...                    ...                   ...
# 192                   False                  False                 False
# 193                   False                  False                 False
# 194                   False                   True                 False
# 195                   False                  False                 False
# 196                   False                  False                 False
#
#      Municipality_Malling  Municipality_Risskov  Municipality_Skødstrup  \
# 0                   False                 False                   False
# 1                   False                 False                   False
# 2                   False                 False                   False
# 3                   False                 False                   False
# 4                   False                 False                   False
# ..                    ...                   ...                     ...
# 192                 False                 False                   False
# 193                 False                 False                   False
# 194                 False                 False                   False
# 195                 False                  True                   False
# 196                 False                  True                   False
#
#      Municipality_Solbjerg  Municipality_Tilst  Municipality_Tranbjerg J  \
# 0                    False               False                      True
# 1                    False               False                     False
# 2                    False                True                     False
# 3                     True               False                     False
# 4                    False               False                     False
# ..                     ...                 ...                       ...
# 192                  False               False                     False
# 193                  False               False                     False
# 194                  False               False                     False
# 195                  False               False                     False
# 196                  False               False                     False
#
#      Municipality_Trige  Municipality_Viby J  Location_central  \
# 0                 False                False             False
# 1                 False                False             False
# 2                 False                False             False
# 3                 False                False             False
# 4                 False                 True             False
# ..                  ...                  ...               ...
# 192                True                False             False
# 193                True                False             False
# 194               False                False             False
# 195               False                False             False
# 196               False                False             False
#
#      Location_downtown  Location_rural  Location_suburban  Location_urban  \
# 0                False            True              False           False
# 1                 True           False              False           False
# 2                False           False               True           False
# 3                False           False               True           False
# 4                False           False              False            True
# ..                 ...             ...                ...             ...
# 192              False            True              False           False
# 193              False           False               True           False
# 194              False           False               True           False
# 195              False           False               True           False
# 196              False           False               True           False
#
#      #Bathrooms_1  #Bathrooms_1-1.5 bathrooms  #Bathrooms_2-2.5 bathrooms  \
# 0           False                        True                       False
# 1           False                        True                       False
# 2           False                       False                        True
# 3           False                       False                        True
# 4           False                        True                       False
# ..            ...                         ...                         ...
# 192         False                       False                       False
# 193         False                       False                        True
# 194         False                        True                       False
# 195         False                       False                       False
# 196         False                        True                       False
#
#      #Bathrooms_3+ bathrooms  #Bathrooms_not_stated  Cond.house_fixer-upper  \
# 0                      False                  False                   False
# 1                      False                  False                   False
# 2                      False                  False                   False
# 3                      False                  False                   False
# 4                      False                  False                   False
# ..                       ...                    ...                     ...
# 192                    False                   True                   False
# 193                    False                  False                   False
# 194                    False                  False                    True
# 195                     True                  False                   False
# 196                    False                  False                   False
#
#      Cond.house_new construction  Cond.house_not_stated  Cond.house_renovated  \
# 0                          False                   True                 False
# 1                          False                  False                  True
# 2                           True                  False                 False
# 3                          False                  False                 False
# 4                           True                  False                 False
# ..                           ...                    ...                   ...
# 192                        False                   True                 False
# 193                        False                  False                  True
# 194                        False                  False                 False
# 195                        False                  False                  True
# 196                        False                  False                  True
#
#      Cond.house_well-maintained  View_city  View_no view  View_not_stated  \
# 0                         False      False          True            False
# 1                         False      False          True            False
# 2                         False      False         False            False
# 3                          True      False          True            False
# 4                         False       True         False            False
# ..                          ...        ...           ...              ...
# 192                       False      False          True            False
# 193                       False      False          True            False
# 194                       False       True         False            False
# 195                       False      False          True            False
# 196                       False      False          True            False
#
#      View_sea  Heating_type_Gulvvarme  Heating_type_Radiators  \
# 0       False                   False                   False
# 1       False                   False                   False
# 2       False                   False                   False
# 3       False                   False                   False
# 4       False                   False                   False
# ..        ...                     ...                     ...
# 192     False                   False                   False
# 193     False                   False                   False
# 194     False                   False                   False
# 195     False                   False                   False
# 196     False                   False                   False
#
#      Heating_type_Var­me­gen­vin­dings­an­læg  Heating_type_fjernvarme  \
# 0                                       False                    False
# 1                                       False                    False
# 2                                       False                    False
# 3                                       False                    False
# 4                                       False                    False
# ..                                        ...                      ...
# 192                                     False                    False
# 193                                     False                    False
# 194                                     False                    False
# 195                                     False                    False
# 196                                     False                    False
#
#      Heating_type_floor heating  Heating_type_not_stated  \
# 0                         False                     True
# 1                         False                     True
# 2                         False                     True
# 3                         False                     True
# 4                         False                     True
# ..                          ...                      ...
# 192                       False                     True
# 193                       False                    False
# 194                       False                     True
# 195                        True                    False
# 196                       False                     True
#
#      cond.house_fixer-upper  cond.house_new construction  \
# 0                     False                        False
# 1                     False                        False
# 2                     False                         True
# 3                     False                        False
# 4                     False                         True
# ..                      ...                          ...
# 192                   False                        False
# 193                   False                        False
# 194                    True                        False
# 195                   False                        False
# 196                   False                        False
#
#      cond.house_not_stated  cond.house_renovated  cond.house_well-maintained  \
# 0                     True                 False                       False
# 1                    False                  True                       False
# 2                    False                 False                       False
# 3                    False                 False                        True
# 4                    False                 False                       False
# ..                     ...                   ...                         ...
# 192                   True                 False                       False
# 193                  False                  True                       False
# 194                  False                 False                       False
# 195                  False                  True                       False
# 196                  False                  True                       False
#
#      Ask.price_log  Monthly_ownership_cost_log
# 0        14.731401                    7.810353
# 1        15.066844                    8.273337
# 2        14.826384                    7.877776
# 3        15.110238                    8.072155
# 4        13.996998                    7.625595
# ..             ...                         ...
# 192      14.603968                    7.781139
# 193      14.861074                    7.676010
# 194      15.037814                    8.178358
# 195      15.067702                    8.234830
# 196      14.690146                    8.113427
#
# [189 rows x 76 columns]

# %% [markdown]
# # Partition into test and train sets

# %%
## Check for near-zero variance

# Calculate the variance of each feature
variance = data.var()

# Set a threshold for near-zero variance 
threshold = 0.01

# Identify features with near-zero variance
near_zero_variance_features = variance[variance < threshold]

# Print the features with near-zero variance
print("Features with near-zero variance:")
print(near_zero_variance_features) # No features with zero or near-zero variance

# Extract features (X) and target (y) from the data
y = np.exp(data['Ask.price_log']) # Transfrom variable back to original state
X = data.drop(columns=['Ask.price_log'])

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)
# Out:
# Features with near-zero variance:
# Series([], dtype: float64)

# %% [markdown]
# # Make Model

# %%
# Make hyperparameter grid for tuning
param_grid = {
    'n_estimators': [50, 100, 200, 500], # Amount of trees
    'max_depth': [None, 10, 20, 30], # How deep the trees in the forest can go
    'min_samples_split': [2, 5, 10], # Specifies the minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4], # Specifies the minimum number of samples required to be at a leaf node.
    'max_features': ['sqrt', 'log2'], # Specifies the method used to select the number of random features to be considered at each split

}


# Initialize Random Forest regressor
rf_regressor = RandomForestRegressor(random_state = 123, # Seed
                                       bootstrap = True) # Small dataset - Use bootstrapping
                                       
# Perform grid search using cross-validation
grid_search = GridSearchCV(estimator=rf_regressor, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Best Parameters: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# Best Score: -2811159774597.3037

# %% [markdown]
# # Make Predictions & Assess Accuracy

# %%
import statistics
# Evaluate the best model on the test set
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# Evaluate MSE
rmse = root_mean_squared_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
me = statistics.mean(y_test-y_pred)
print("RMSE:", rmse) # RMSE 1148518 DKK
print("MAE:", mae)
print("MAPE:", mape)
print("ME:", me)

# Create DataFrame for y_pred and y_test
df = pd.DataFrame({'y_test': y_test, 'y_pred': y_pred})

df['diff'] = df['y_test'] - df['y_pred']

# Find the row ID corresponding to the maximum difference
max_diff_row_id = df['diff'].idxmax()

# Print the maximum difference and its corresponding row ID
print("Maximum Difference:", max(df['diff']))
print("Row ID with Maximum Difference:", max_diff_row_id)

# Calculate the mean of y_test
mean_test_value = statistics.mean(y_test)

# Filter the DataFrame based on whether y_test is above or below the mean
above_mean_indices = y_test > mean_test_value
below_mean_indices = ~above_mean_indices

# Get the predictions corresponding to each subset
y_pred_above_mean = y_pred[above_mean_indices]
y_pred_below_mean = y_pred[below_mean_indices]

# Get the true values corresponding to each subset
y_test_above_mean = y_test[above_mean_indices]
y_test_below_mean = y_test[below_mean_indices]

# Calculate RMSE for values above the mean
rmse_above_mean = root_mean_squared_error(y_test_above_mean, y_pred_above_mean)

# Calculate RMSE for values below the mean
rmse_below_mean = root_mean_squared_error(y_test_below_mean, y_pred_below_mean)

print("RMSE for values above the mean:", rmse_above_mean)
print("RMSE for values below the mean:", rmse_below_mean)

# Check RMSE for each real estate Type

# Select specific columns from X_test
columns_to_concat = ['Type_Andelsbolig', 'Type_Ejerlejlighed', 'Type_Landejendom', 'Type_Rækkehus', 'Type_Villa']
X_test_selected = X_test[columns_to_concat]

# Concatenate the selected columns from X_test with the existing DataFrame df
df = pd.concat([df, X_test_selected], axis=1)

# Create empty dictionaries to store RMSE values for each type
rmse_above_mean_dict = {}
rmse_below_mean_dict = {}

# Iterate over each real estate type
for real_estate_type in ['Type_Andelsbolig', 'Type_Ejerlejlighed', 'Type_Landejendom', 'Type_Rækkehus', 'Type_Villa']:
    # Filter the DataFrame based on whether y_test is above or below the mean for the current type
    above_mean_indices = df[real_estate_type] == 1
    below_mean_indices = ~above_mean_indices

    # Get the predictions and true values corresponding to each subset for the current type
    y_pred_above_mean = y_pred[above_mean_indices]
    y_pred_below_mean = y_pred[below_mean_indices]
    y_test_above_mean = y_test[above_mean_indices]
    y_test_below_mean = y_test[below_mean_indices]

    # Calculate RMSE for values above the mean for the current type
    rmse_above_mean = root_mean_squared_error(y_test_above_mean, y_pred_above_mean)
    rmse_above_mean_dict[real_estate_type] = rmse_above_mean

    # Calculate RMSE for values below the mean for the current type
    rmse_below_mean = root_mean_squared_error(y_test_below_mean, y_pred_below_mean)
    rmse_below_mean_dict[real_estate_type] = rmse_below_mean

# Print RMSE for values above and below the mean for each real estate type
for real_estate_type in ['Type_Andelsbolig', 'Type_Ejerlejlighed', 'Type_Landejendom', 'Type_Rækkehus', 'Type_Villa']:
    print(f"RMSE for values above the mean ({real_estate_type}):", rmse_above_mean_dict[real_estate_type])
    print(f"RMSE for values below the mean ({real_estate_type}):", rmse_below_mean_dict[real_estate_type])

# Print the DataFrame
print(df)

# Save model

joblib.dump(best_model, 'Full_Random_Forest_Reg.pkl')
# Out:
# RMSE: 1148518.8239029888
# MSE: 1319095488859.5044
# MAE: 891624.873684211
# MAPE: 0.34338027855820114
# ME: -4161.005263157263
# Maximum Difference: 2886320.0000000065
# Row ID with Maximum Difference: 19
# RMSE for values above the mean: 1336426.143446104
# RMSE for values below the mean: 970101.5251139172
# RMSE for values above the mean (Type_Andelsbolig): 1985252.1600000008
# RMSE for values below the mean (Type_Andelsbolig): 1117240.8392623235
# RMSE for values above the mean (Type_Ejerlejlighed): 825671.9468747253
# RMSE for values below the mean (Type_Ejerlejlighed): 1423823.984509149
# RMSE for values above the mean (Type_Landejendom): 2278800.0000000037
# RMSE for values below the mean (Type_Landejendom): 1101996.9482552186
# RMSE for values above the mean (Type_Rækkehus): 1034724.8252338078
# RMSE for values below the mean (Type_Rækkehus): 1168622.2629785356
# RMSE for values above the mean (Type_Villa): 1446819.1641330884
# RMSE for values below the mean (Type_Villa): 1021077.3658884849
#         y_test      y_pred        diff  Type_Andelsbolig  Type_Ejerlejlighed  \
# 78   3848000.0  3198520.00   649480.00             False                True
# 26   1195000.0  2408020.00 -1213020.00             False                True
# 42   3495000.0  3197580.00   297420.00             False                True
# 4    1199000.0  2207524.84 -1008524.84             False                True
# 167  1695000.0  4402380.00 -2707380.00             False               False
# 146  1695000.0  2343880.00  -648880.00             False                True
# 92   5998000.0  3719200.00  2278800.00             False               False
# 64   2795000.0  2807300.00   -12300.00             False               False
# 54   3595000.0  2646960.00   948040.00             False                True
# 116  2295000.0  2809740.00  -514740.00             False                True
# 19   8995000.0  6108680.00  2886320.00             False               False
# 158  1195000.0  1868550.46  -673550.46             False                True
# 168  1548000.0  1996364.84  -448364.84             False                True
# 43   5995000.0  3965760.00  2029240.00             False                True
# 63   2495000.0  3020120.00  -525120.00             False                True
# 106  1995000.0  2525084.84  -530084.84             False               False
# 112  1595000.0  2800916.82 -1205916.82             False                True
# 154  1995000.0  2731976.82  -736976.82             False                True
# 102  4299000.0  5155740.00  -856740.00             False               False
# 162  3695000.0  3764820.00   -69820.00             False                True
# 188  6750000.0  5542184.84  1207815.16             False               False
# 155  1995000.0  2242993.64  -247993.64             False                True
# 169  5495000.0  4040300.00  1454700.00             False               False
# 31   1395000.0  2327720.00  -932720.00             False                True
# 95   4695000.0  3467696.82  1227303.18             False               False
# 176  2998000.0  3003260.00    -5260.00             False                True
# 149  2995000.0  3064456.82   -69456.82             False                True
# 130  4998000.0  3631820.00  1366180.00             False               False
# 160  1750000.0  2686040.00  -936040.00             False                True
# 87   1506016.0  3491268.16 -1985252.16              True               False
# 175  4195000.0  3942884.84   252115.16             False               False
# 38   2850000.0  2912473.64   -62473.64             False               False
# 83   3695000.0  4332280.00  -637280.00             False               False
# 118  5295000.0  3631820.00  1663180.00             False               False
# 110  4195000.0  3916160.00   278840.00             False               False
# 34   1898000.0  2331676.82  -433676.82             False                True
# 23   3995000.0  4553360.00  -558360.00             False               False
# 51   3200000.0  2877620.00   322380.00             False               False
#
#      Type_Landejendom  Type_Rækkehus  Type_Villa
# 78              False          False       False
# 26              False          False       False
# 42              False          False       False
# 4               False          False       False
# 167             False          False        True
# 146             False          False       False
# 92               True          False       False
# 64              False           True       False
# 54              False          False       False
# 116             False          False       False
# 19              False          False        True
# 158             False          False       False
# 168             False          False       False
# 43              False          False       False
# 63              False          False       False
# 106             False           True       False
# 112             False          False       False
# 154             False          False       False
# 102             False          False        True
# 162             False          False       False
# 188             False          False        True
# 155             False          False       False
# 169             False          False        True
# 31              False          False       False
# 95              False           True       False
# 176             False          False       False
# 149             False          False       False
# 130             False           True       False
# 160             False          False       False
# 87              False          False       False
# 175             False          False        True
# 38              False           True       False
# 83              False          False        True
# 118             False           True       False
# 110             False          False        True
# 34              False          False       False
# 23              False          False        True
# 51              False          False        True
#         y_test      y_pred        diff  Type_Andelsbolig  Type_Ejerlejlighed  \
# 78   3848000.0  3198520.00   649480.00             False                True
# 26   1195000.0  2408020.00 -1213020.00             False                True
# 42   3495000.0  3197580.00   297420.00             False                True
# 4    1199000.0  2207524.84 -1008524.84             False                True
# 167  1695000.0  4402380.00 -2707380.00             False               False
# 146  1695000.0  2343880.00  -648880.00             False                True
# 92   5998000.0  3719200.00  2278800.00             False               False
# 64   2795000.0  2807300.00   -12300.00             False               False
# 54   3595000.0  2646960.00   948040.00             False                True
# 116  2295000.0  2809740.00  -514740.00             False                True
# 19   8995000.0  6108680.00  2886320.00             False               False
# 158  1195000.0  1868550.46  -673550.46             False                True
# 168  1548000.0  1996364.84  -448364.84             False                True
# 43   5995000.0  3965760.00  2029240.00             False                True
# 63   2495000.0  3020120.00  -525120.00             False                True
# 106  1995000.0  2525084.84  -530084.84             False               False
# 112  1595000.0  2800916.82 -1205916.82             False                True
# 154  1995000.0  2731976.82  -736976.82             False                True
# 102  4299000.0  5155740.00  -856740.00             False               False
# 162  3695000.0  3764820.00   -69820.00             False                True
# 188  6750000.0  5542184.84  1207815.16             False               False
# 155  1995000.0  2242993.64  -247993.64             False                True
# 169  5495000.0  4040300.00  1454700.00             False               False
# 31   1395000.0  2327720.00  -932720.00             False                True
# 95   4695000.0  3467696.82  1227303.18             False               False
# 176  2998000.0  3003260.00    -5260.00             False                True
# 149  2995000.0  3064456.82   -69456.82             False                True
# 130  4998000.0  3631820.00  1366180.00             False               False
# 160  1750000.0  2686040.00  -936040.00             False                True
# 87   1506016.0  3491268.16 -1985252.16              True               False
# 175  4195000.0  3942884.84   252115.16             False               False
# 38   2850000.0  2912473.64   -62473.64             False               False
# 83   3695000.0  4332280.00  -637280.00             False               False
# 118  5295000.0  3631820.00  1663180.00             False               False
# 110  4195000.0  3916160.00   278840.00             False               False
# 34   1898000.0  2331676.82  -433676.82             False                True
# 23   3995000.0  4553360.00  -558360.00             False               False
# 51   3200000.0  2877620.00   322380.00             False               False
#
#      Type_Landejendom  Type_Rækkehus  Type_Villa
# 78              False          False       False
# 26              False          False       False
# 42              False          False       False
# 4               False          False       False
# 167             False          False        True
# 146             False          False       False
# 92               True          False       False
# 64              False           True       False
# 54              False          False       False
# 116             False          False       False
# 19              False          False        True
# 158             False          False       False
# 168             False          False       False
# 43              False          False       False
# 63              False          False       False
# 106             False           True       False
# 112             False          False       False
# 154             False          False       False
# 102             False          False        True
# 162             False          False       False
# 188             False          False        True
# 155             False          False       False
# 169             False          False        True
# 31              False          False       False
# 95              False           True       False
# 176             False          False       False
# 149             False          False       False
# 130             False           True       False
# 160             False          False       False
# 87              False          False       False
# 175             False          False        True
# 38              False           True       False
# 83              False          False        True
# 118             False           True       False
# 110             False          False        True
# 34              False          False       False
# 23              False          False        True
# 51              False          False        True
# ['Full_Random_Forest_Reg.pkl']

# %% [markdown]
# # Assess Feature Importance

# %%
# Fit optimal RF model
rf_regressor.fit(X_train, y_train)

# Get feature importances
feature_importances = rf_regressor.feature_importances_

# Sort feature importances in descending order
indices = np.argsort(feature_importances)[::-1]

# Print the feature ranking with names
print("Feature ranking:")
for f in range(X_train.shape[1]):
    feature_name = X_train.columns[indices[f]]  # Get the name of the feature
    print(f"{f + 1}. {feature_name} ({feature_importances[indices[f]]})")

# Plot the feature importances
plt.figure(figsize=(10, 6))
plt.title("Feature Importances")
plt.bar(range(X_train.shape[1]), feature_importances[indices], color="b", align="center")
plt.xticks(range(X_train.shape[1]), X_train.columns[indices], rotation=90)  # Use feature names for xticks
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Fit optimal RF model
# ----> 2 rf_regressor.fit(X_train, y_train)
#       4 # Get feature importances
#       5 feature_importances = rf_regressor.feature_importances_
#
# NameError: name 'rf_regressor' is not defined

# %% [markdown]
# # Make New Model With Top-10 Most Important Features

# %%
# Get indices of the top 10 most important features
top_feature_indices = indices[:10]

# Select top 10 for x test and x train
X_train_top_features = X_train.iloc[:, top_feature_indices]
X_test_top_features = X_test.iloc[:, top_feature_indices]

# Print the shape of the new X_train DataFrame to check if selection has been done correctly
print(X_train_top_features.shape)
print(X_test_top_features.shape)
# Out:
# (151, 10)
# (38, 10)

# %% [markdown]
# # Re-estimate Model

# %%
# Make hyperparameter grid for tuning
param_grid = {
    'n_estimators': [50, 100, 200, 500], # Amount of trees
    'max_depth': [None, 10, 20, 30], # How deep the trees in the forest can go
    'min_samples_split': [2, 5, 10], # Specifies the minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4], # Specifies the minimum number of samples required to be at a leaf node.
    'max_features': ['sqrt', 'log2'], # Specifies the method used to select the number of random features to be considered at each split

}


# Initialize Random Forest regressor
rf_regressor = RandomForestRegressor(random_state = 123, # Seed
                                       bootstrap = True) # Small dataset - Use bootstrapping
                                       
# Perform grid search using cross-validation
grid_search = GridSearchCV(estimator=rf_regressor, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train_top_features, y_train) # Change X_train to modified training set

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Best Parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# Best Score: -1958377041018.8594

# %% [markdown]
# # Assess Model

# %%
# Evaluate the best model on the test set
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test_top_features)

# Evaluate MSE
rmse = root_mean_squared_error(y_test, y_pred)
print("RMSE:", rmse) # RMSE 1373840 DKK

# Create DataFrame for y_pred and y_test
df = pd.DataFrame({'y_test': y_test, 'y_pred': y_pred})

# Print the DataFrame
print(df)

# Save model

joblib.dump(best_model, 'Top10_features_Random_Forest_Reg.pkl')
# Out:
# RMSE: 1373840.5070363523
#         y_test      y_pred
# 78   3848000.0  2543340.00
# 26   1195000.0  1756960.00
# 42   3495000.0  3865804.84
# 4    1199000.0  1855640.00
# 167  1695000.0  4879900.00
# 146  1695000.0  2214060.00
# 92   5998000.0  3489600.00
# 64   2795000.0  2521000.00
# 54   3595000.0  2848660.00
# 116  2295000.0  2497180.00
# 19   8995000.0  4642176.82
# 158  1195000.0  1322820.00
# 168  1548000.0  1373680.00
# 43   5995000.0  7730400.00
# 63   2495000.0  2402440.00
# 106  1995000.0  2405709.68
# 112  1595000.0  2400340.00
# 154  1995000.0  2372280.00
# 102  4299000.0  4773080.00
# 162  3695000.0  3905800.00
# 188  6750000.0  4074500.00
# 155  1995000.0  2194020.00
# 169  5495000.0  3951620.00
# 31   1395000.0  1566060.00
# 95   4695000.0  4129193.64
# 176  2998000.0  2944144.84
# 149  2995000.0  3476700.00
# 130  4998000.0  4045996.82
# 160  1750000.0  2254120.00
# 87   1506016.0  5263096.96
# 175  4195000.0  3919300.00
# 38   2850000.0  2743120.00
# 83   3695000.0  4731620.00
# 118  5295000.0  4045996.82
# 110  4195000.0  4740860.00
# 34   1898000.0  1962820.00
# 23   3995000.0  3955040.00
# 51   3200000.0  2978520.00
# ['Top10_features_Random_Forest_Reg.pkl']
